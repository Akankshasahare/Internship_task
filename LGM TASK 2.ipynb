# %% [markdown]
# # LGMVIP DATA SCIENCE INTERNSHIP

# %% [markdown]
# # Task 2 : Stock Market Prediction And Forecasting Using Stacked LSTM

# %% [markdown]
# # Import The Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = "https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv"
train_data = pd.read_csv(data)
training_set = train_data.iloc[:, 1:2].values

# %%
train_data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
close_data = train_data['Close']

# %%
close_data
# Out:
# 0       233.75
# 1       233.25
# 2       234.25
# 3       236.10
# 4       233.30
#          ...
# 2030    118.65
# 2031    117.60
# 2032    120.65
# 2033    120.90
# 2034    121.55
# Name: Close, Length: 2035, dtype: float64

# %%
plt.plot(close_data)

# %% [markdown]
# # Data Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))
close_data = scaler.fit_transform(np.array(close_data).reshape(-1,1))

# %%
close_data.shape
# Out:
# (2035, 1)

# %%
print(close_data)
# Out:
# [[0.62418301]
#  [0.62214052]
#  [0.62622549]
#  ...
#  [0.1621732 ]
#  [0.16319444]
#  [0.16584967]]

# %% [markdown]
# # Train Test Split

# %%
training_size = int(len(close_data)*0.75)
test_size = len(close_data) - training_size
train_data, test_data = close_data[0:training_size,:], close_data[training_size:len(close_data),:1]

# %%
def create_data(data, time_step=1):
    dataX,dataY = [],[]
    for i in range(len(data) - time_step - 1):
        a = data[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(data[i+time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
x_train,y_train = create_data(train_data,time_step)
x_test, y_test = create_data(test_data,time_step)

# %% [markdown]
# # Reshape the inputs to be

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1],1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1],1)

# %% [markdown]
# # Model Building

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (100,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 100, 50)           10400
#
#  lstm_4 (LSTM)               (None, 100, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train, validation_data=(x_test, y_test),epochs=100, batch_size = 64, verbose = 1)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 13s 261ms/step - loss: 0.0213 - val_loss: 0.0087
# Epoch 2/100
# 23/23 [==============================] - 4s 160ms/step - loss: 0.0028 - val_loss: 7.9685e-04
# Epoch 3/100
# 23/23 [==============================] - 4s 169ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 4/100
# 23/23 [==============================] - 4s 170ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 5/100
# 23/23 [==============================] - 4s 166ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 6/100
# 23/23 [==============================] - 4s 173ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 7/100
# 23/23 [==============================] - 4s 175ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 8/100
# 23/23 [==============================] - 4s 160ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 9/100
# 23/23 [==============================] - 4s 176ms/step - loss: 0.0012 - val_loss: 9.9392e-04
# Epoch 10/100
# 23/23 [==============================] - 4s 172ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 11/100
# 23/23 [==============================] - 4s 182ms/step - loss: 0.0011 - val_loss: 8.1526e-04
# Epoch 12/100
# 23/23 [==============================] - 4s 168ms/step - loss: 0.0010 - val_loss: 8.8148e-04
# Epoch 13/100
# 23/23 [==============================] - 4s 173ms/step - loss: 9.9595e-04 - val_loss: 7.3549e-04
# Epoch 14/100
# 23/23 [==============================] - 4s 182ms/step - loss: 9.1375e-04 - val_loss: 8.1442e-04
# Epoch 15/100
# 23/23 [==============================] - 4s 173ms/step - loss: 8.7355e-04 - val_loss: 8.2765e-04
# Epoch 16/100
# 23/23 [==============================] - 4s 160ms/step - loss: 9.0658e-04 - val_loss: 6.7586e-04
# Epoch 17/100
# 23/23 [==============================] - 4s 165ms/step - loss: 8.7978e-04 - val_loss: 7.1344e-04
# Epoch 18/100
# 23/23 [==============================] - 4s 167ms/step - loss: 8.5360e-04 - val_loss: 8.3584e-04
# Epoch 19/100
# 23/23 [==============================] - 4s 159ms/step - loss: 8.1107e-04 - val_loss: 6.5463e-04
# Epoch 20/100
# 23/23 [==============================] - 4s 158ms/step - loss: 7.6600e-04 - val_loss: 7.6340e-04
# Epoch 21/100
# 23/23 [==============================] - 4s 166ms/step - loss: 7.4484e-04 - val_loss: 7.3796e-04
# Epoch 22/100
# 23/23 [==============================] - 4s 172ms/step - loss: 7.8002e-04 - val_loss: 5.4777e-04
# Epoch 23/100
# 23/23 [==============================] - 4s 169ms/step - loss: 7.9609e-04 - val_loss: 0.0010
# Epoch 24/100
# 23/23 [==============================] - 4s 168ms/step - loss: 7.8068e-04 - val_loss: 8.4604e-04
# Epoch 25/100
# 23/23 [==============================] - 4s 177ms/step - loss: 7.2531e-04 - val_loss: 7.8044e-04
# Epoch 26/100
# 23/23 [==============================] - 4s 174ms/step - loss: 7.1949e-04 - val_loss: 9.5920e-04
# Epoch 27/100
# 23/23 [==============================] - 4s 164ms/step - loss: 6.5951e-04 - val_loss: 0.0010
# Epoch 28/100
# 23/23 [==============================] - 4s 175ms/step - loss: 6.5388e-04 - val_loss: 7.4256e-04
# Epoch 29/100
# 23/23 [==============================] - 4s 181ms/step - loss: 6.5498e-04 - val_loss: 6.8834e-04
# Epoch 30/100
# 23/23 [==============================] - 4s 178ms/step - loss: 6.1771e-04 - val_loss: 6.2988e-04
# Epoch 31/100
# 23/23 [==============================] - 4s 173ms/step - loss: 6.1048e-04 - val_loss: 6.9950e-04
# Epoch 32/100
# 23/23 [==============================] - 4s 164ms/step - loss: 6.1743e-04 - val_loss: 7.9328e-04
# Epoch 33/100
# 23/23 [==============================] - 4s 175ms/step - loss: 6.6117e-04 - val_loss: 0.0013
# Epoch 34/100
# 23/23 [==============================] - 4s 164ms/step - loss: 6.8086e-04 - val_loss: 5.0842e-04
# Epoch 35/100
# 23/23 [==============================] - 4s 165ms/step - loss: 6.7188e-04 - val_loss: 6.5705e-04
# Epoch 36/100
# 23/23 [==============================] - 4s 183ms/step - loss: 5.4234e-04 - val_loss: 7.1247e-04
# Epoch 37/100
# 23/23 [==============================] - 4s 171ms/step - loss: 5.8555e-04 - val_loss: 9.2358e-04
# Epoch 38/100
# 23/23 [==============================] - 4s 184ms/step - loss: 5.8051e-04 - val_loss: 5.6302e-04
# Epoch 39/100
# 23/23 [==============================] - 4s 178ms/step - loss: 5.0013e-04 - val_loss: 5.5791e-04
# Epoch 40/100
# 23/23 [==============================] - 4s 175ms/step - loss: 5.0521e-04 - val_loss: 6.6109e-04
# Epoch 41/100
# 23/23 [==============================] - 4s 178ms/step - loss: 4.9951e-04 - val_loss: 5.1144e-04
# Epoch 42/100
# 23/23 [==============================] - 4s 179ms/step - loss: 4.7345e-04 - val_loss: 6.2737e-04
# Epoch 43/100
# 23/23 [==============================] - 4s 172ms/step - loss: 5.3255e-04 - val_loss: 6.8799e-04
# Epoch 44/100
# 23/23 [==============================] - 4s 165ms/step - loss: 5.1808e-04 - val_loss: 6.2270e-04
# Epoch 45/100
# 23/23 [==============================] - 4s 175ms/step - loss: 4.8186e-04 - val_loss: 5.4827e-04
# Epoch 46/100
# 23/23 [==============================] - 4s 172ms/step - loss: 4.4950e-04 - val_loss: 5.5822e-04
# Epoch 47/100
# 23/23 [==============================] - 4s 173ms/step - loss: 4.3030e-04 - val_loss: 5.3857e-04
# Epoch 48/100
# 23/23 [==============================] - 4s 171ms/step - loss: 4.5293e-04 - val_loss: 3.1691e-04
# Epoch 49/100
# 23/23 [==============================] - 4s 183ms/step - loss: 5.9583e-04 - val_loss: 3.3707e-04
# Epoch 50/100
# 23/23 [==============================] - 4s 176ms/step - loss: 4.6960e-04 - val_loss: 3.7855e-04
# Epoch 51/100
# 23/23 [==============================] - 4s 172ms/step - loss: 4.0588e-04 - val_loss: 3.9032e-04
# Epoch 52/100
# 23/23 [==============================] - 4s 171ms/step - loss: 4.1233e-04 - val_loss: 3.9103e-04
# Epoch 53/100
# 23/23 [==============================] - 4s 176ms/step - loss: 4.0267e-04 - val_loss: 5.5862e-04
# Epoch 54/100
# 23/23 [==============================] - 4s 192ms/step - loss: 4.0062e-04 - val_loss: 3.3940e-04
# Epoch 55/100
# 23/23 [==============================] - 4s 187ms/step - loss: 3.9901e-04 - val_loss: 3.3975e-04
# Epoch 56/100
# 23/23 [==============================] - 4s 168ms/step - loss: 4.2586e-04 - val_loss: 2.7922e-04
# Epoch 57/100
# 23/23 [==============================] - 4s 189ms/step - loss: 4.8726e-04 - val_loss: 4.4475e-04
# Epoch 58/100
# 23/23 [==============================] - 4s 184ms/step - loss: 4.2566e-04 - val_loss: 3.9740e-04
# Epoch 59/100
# 23/23 [==============================] - 6s 257ms/step - loss: 4.1594e-04 - val_loss: 5.7387e-04
# Epoch 60/100
# 23/23 [==============================] - 6s 276ms/step - loss: 3.8688e-04 - val_loss: 4.1023e-04
# Epoch 61/100
# 23/23 [==============================] - 5s 218ms/step - loss: 3.4567e-04 - val_loss: 3.0993e-04
# Epoch 62/100
# 23/23 [==============================] - 5s 215ms/step - loss: 3.6578e-04 - val_loss: 3.1601e-04
# Epoch 63/100
# 23/23 [==============================] - 5s 221ms/step - loss: 3.4529e-04 - val_loss: 3.3267e-04
# Epoch 64/100
# 23/23 [==============================] - 5s 219ms/step - loss: 3.3387e-04 - val_loss: 3.1305e-04
# Epoch 65/100
# 23/23 [==============================] - 4s 182ms/step - loss: 2.9730e-04 - val_loss: 2.6834e-04
# Epoch 66/100
# 23/23 [==============================] - 4s 177ms/step - loss: 3.1751e-04 - val_loss: 3.5921e-04
# Epoch 67/100
# 23/23 [==============================] - 4s 176ms/step - loss: 2.9249e-04 - val_loss: 4.7080e-04
# Epoch 68/100
# 23/23 [==============================] - 4s 174ms/step - loss: 2.9089e-04 - val_loss: 3.7115e-04
# Epoch 69/100
# 23/23 [==============================] - 5s 203ms/step - loss: 2.9215e-04 - val_loss: 4.0680e-04
# Epoch 70/100
# 23/23 [==============================] - 5s 199ms/step - loss: 3.3218e-04 - val_loss: 2.7475e-04
# Epoch 71/100
# 23/23 [==============================] - 5s 217ms/step - loss: 2.9669e-04 - val_loss: 2.3922e-04
# Epoch 72/100
# 23/23 [==============================] - 4s 191ms/step - loss: 2.9703e-04 - val_loss: 4.2308e-04
# Epoch 73/100
# 23/23 [==============================] - 4s 180ms/step - loss: 3.0544e-04 - val_loss: 2.5595e-04
# Epoch 74/100
# 23/23 [==============================] - 4s 172ms/step - loss: 2.6414e-04 - val_loss: 2.6499e-04
# Epoch 75/100
# 23/23 [==============================] - 4s 176ms/step - loss: 2.6067e-04 - val_loss: 2.5993e-04
# Epoch 76/100
# 23/23 [==============================] - 4s 169ms/step - loss: 2.5021e-04 - val_loss: 2.7181e-04
# Epoch 77/100
# 23/23 [==============================] - 4s 173ms/step - loss: 2.5327e-04 - val_loss: 2.7756e-04
# Epoch 78/100
# 23/23 [==============================] - 4s 163ms/step - loss: 2.5719e-04 - val_loss: 2.6016e-04
# Epoch 79/100
# 23/23 [==============================] - 4s 176ms/step - loss: 2.5920e-04 - val_loss: 2.4493e-04
# Epoch 80/100
# 23/23 [==============================] - 4s 164ms/step - loss: 2.5580e-04 - val_loss: 3.4151e-04
# Epoch 81/100
# 23/23 [==============================] - 4s 167ms/step - loss: 2.9500e-04 - val_loss: 2.1558e-04
# Epoch 82/100
# 23/23 [==============================] - 4s 175ms/step - loss: 2.8607e-04 - val_loss: 2.1774e-04
# Epoch 83/100
# 23/23 [==============================] - 4s 170ms/step - loss: 2.5618e-04 - val_loss: 1.8237e-04
# Epoch 84/100
# 23/23 [==============================] - 4s 173ms/step - loss: 2.6422e-04 - val_loss: 3.6924e-04
# Epoch 85/100
# 23/23 [==============================] - 4s 172ms/step - loss: 2.4476e-04 - val_loss: 1.8583e-04
# Epoch 86/100
# 23/23 [==============================] - 4s 174ms/step - loss: 2.9929e-04 - val_loss: 3.3842e-04
# Epoch 87/100
# 23/23 [==============================] - 4s 172ms/step - loss: 2.3764e-04 - val_loss: 2.0637e-04
# Epoch 88/100
# 23/23 [==============================] - 5s 237ms/step - loss: 2.4548e-04 - val_loss: 2.4840e-04
# Epoch 89/100
# 23/23 [==============================] - 5s 204ms/step - loss: 2.2855e-04 - val_loss: 1.8160e-04
# Epoch 90/100
# 23/23 [==============================] - 4s 175ms/step - loss: 2.2883e-04 - val_loss: 1.8155e-04
# Epoch 91/100
# 23/23 [==============================] - 4s 172ms/step - loss: 2.4105e-04 - val_loss: 1.7617e-04
# Epoch 92/100
# 23/23 [==============================] - 4s 175ms/step - loss: 2.2238e-04 - val_loss: 1.8921e-04
# Epoch 93/100
# 23/23 [==============================] - 4s 174ms/step - loss: 2.2389e-04 - val_loss: 2.1290e-04
# Epoch 94/100
# 23/23 [==============================] - 4s 188ms/step - loss: 2.7631e-04 - val_loss: 1.6272e-04
# Epoch 95/100
# 23/23 [==============================] - 4s 171ms/step - loss: 2.5247e-04 - val_loss: 2.3447e-04
# Epoch 96/100
# 23/23 [==============================] - 4s 172ms/step - loss: 2.7660e-04 - val_loss: 1.9212e-04
# Epoch 97/100
# 23/23 [==============================] - 4s 175ms/step - loss: 2.3079e-04 - val_loss: 2.6100e-04
# Epoch 98/100
# 23/23 [==============================] - 4s 175ms/step - loss: 2.8288e-04 - val_loss: 2.6670e-04
# Epoch 99/100
# 23/23 [==============================] - 4s 174ms/step - loss: 2.4736e-04 - val_loss: 1.6003e-04
# Epoch 100/100
# 23/23 [==============================] - 4s 173ms/step - loss: 2.5512e-04 - val_loss: 2.2624e-04

# %%
# Predicting the models
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)
# Out:
# 45/45 [==============================] - 3s 32ms/step
# 13/13 [==============================] - 0s 32ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_test, test_predict))
# Out:
# 1567676528.366933

# %%
#Plotting the graphs

#shift train prediction for plotting

look_back = 100
train_predict_plot = np.empty_like(close_data)
train_predict_plot[:,:] = np.nan
train_predict_plot[look_back:len(train_predict)+look_back, :] = train_predict

# shift the test results for plotting
test_predict_plot = np.empty_like(close_data)
test_predict_plot[:,:] = np.nan
test_predict_plot[len(train_predict) + (look_back * 2)+1:len(close_data)-1 :] = test_predict

#plot baseline and predictions
plt.plot(scaler.inverse_transform(close_data))
plt.plot(train_predict_plot)
plt.plot(test_predict_plot)
plt.show()

# %% [markdown]
# # Stock prediction for next 30 days

# %%
len(test_data), x_test.shape
# Out:
# (509, (408, 100, 1))

# %%
x_input = test_data[409:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# %%
lst_output = []
n_step = 100
next_Number_Of_Days = 30
temp_input = [] # Add this to initialize temp_input
i = 0

while(i<next_Number_Of_Days):
    
    if(len(temp_input)>100):
        x_input = np.array(temp_input[1:])
        print("{} day input {} ".format(i,x_input))
        x_input = x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_step, 1))
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {} ".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
    else:
        x_input = np.zeros((1,n_step,1)) # Modify this line to initialize x_input
        yhat = model.predict(x_input,verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i = i+1 
print("lst_output")
# Out:
# [0.01426165]
# 1
# [0.01426165]
# 2
# [0.01426165]
# 3
# [0.01426165]
# 4
# [0.01426165]
# 5
# [0.01426165]
# 6
# [0.01426165]
# 7
# [0.01426165]
# 8
# [0.01426165]
# 9
# [0.01426165]
# 10
# [0.01426165]
# 11
# [0.01426165]
# 12
# [0.01426165]
# 13
# [0.01426165]
# 14
# [0.01426165]
# 15
# [0.01426165]
# 16
# [0.01426165]
# 17
# [0.01426165]
# 18
# [0.01426165]
# 19
# [0.01426165]
# 20
# [0.01426165]
# 21
# [0.01426165]
# 22
# [0.01426165]
# 23
# [0.01426165]
# 24
# [0.01426165]
# 25
# [0.01426165]
# 26
# [0.01426165]
# 27
# [0.01426165]
# 28
# [0.01426165]
# 29
# [0.01426165]
# 30
# lst_output

# %%
day_new = np.arange(1,101)
day_predict = np.arange(101,131)

# %%
df = close_data.tolist()
df.extend(lst_output)

# %%
len(close_data)
# Out:
# 2035

# %%
plt.plot(day_new, scaler.inverse_transform(close_data[1935:]))
plt.plot(day_predict, scaler.inverse_transform(lst_output))
